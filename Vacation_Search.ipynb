# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Store the CSV created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/WeatherPy_challenge.csv")
city_data_df = city_data_df.set_index('City_ID')
city_data_df.head()
# Out:
#                     City Country                 Date    Lat     Lng  \
# City_ID
# 0        Haines Junction      CA  2020-05-08 22:20:43  60.75 -137.51
# 1               Upington      ZA  2020-05-08 22:22:34 -28.45   21.26
# 2              Busselton      AU  2020-05-08 22:19:37 -33.65  115.33
# 3              Jamestown      US  2020-05-08 22:19:30  42.10  -79.24
# 4              Esperance      AU  2020-05-08 22:19:54 -33.87  121.90
#
#          Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# City_ID
# 0           58.51        32          75        5.41       broken clouds
# 1           59.00        33           0        3.36           clear sky
# 2           43.00        75           0        6.42           clear sky
# 3           33.01        79          90       11.41          light snow
# 4           48.20        93          40        6.93    scattered clouds
#
#          Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# City_ID
# ...

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for you trip? "))
rain = str(input("Do you want it to be raining? (yes/no) "))
snow = str(input("Do you want it to be snowing? (yes/no) "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for you trip? 85
# Do you want it to be raining? (yes/no) no
# Do you want it to be snowing? (yes/no) no

# %%
#If statements to filter out cities with rain and snow
if rain == "yes":
    rain_response = city_data_df["Rain inches (last 3 hrs)"] != 0
else:
    rain_response = city_data_df["Rain inches (last 3 hrs)"] == 0
if snow == "yes":
    snow_response = city_data_df["Snow inches (last 3 hrs)"] != 0
else:
    snow_response = city_data_df["Snow inches (last 3 hrs)"] == 0

# %%
# Filter the dataset to find the cities that fit the criteria
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                      (city_data_df["Max Temp"] >= min_temp) & \
                                      (rain_response) & (snow_response)]

# %%
preferred_cities_df
# Out:
#                City Country                 Date    Lat     Lng  Max Temp  \
# City_ID
# 5         Mahebourg      MU  2020-05-08 22:19:42 -20.41   57.70     71.60
# 16             Hilo      US  2020-05-08 22:19:39  19.73 -155.09     84.20
# 17        Bathsheba      BB  2020-05-08 22:22:37  13.22  -59.52     82.40
# 22       Butaritari      KI  2020-05-08 22:19:36   3.07  172.79     82.69
# 24           Avarua      CK  2020-05-08 22:19:38 -21.21 -159.78     82.40
# ...             ...     ...                  ...    ...     ...       ...
# 524           Basco      PH  2020-05-08 22:23:51  20.45  121.97     81.81
# 525         Huarmey      PE  2020-05-08 22:23:52 -10.07  -78.15     72.81
# 528          Sorong      ID  2020-05-08 22:23:52  -0.88  131.25     79.57
# 531       Nhulunbuy      AU  2020-05-08 22:23:52 -12.23  136.77     77.00
# 534            Bati      ET  2020-05-08 22:23:53  11.18   40.02     72.21
#
#          Humidity  Cloudiness  Wind Speed Current Description  \
# ...

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp and coordinates
hotel_df = preferred_cities_df[["City", "Country", "Current Description", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                  City Country Current Description  Max Temp    Lat     Lng  \
# City_ID
# 5           Mahebourg      MU    scattered clouds     71.60 -20.41   57.70
# 16               Hilo      US          few clouds     84.20  19.73 -155.09
# 17          Bathsheba      BB    scattered clouds     82.40  13.22  -59.52
# 22         Butaritari      KI     overcast clouds     82.69   3.07  172.79
# 24             Avarua      CK    scattered clouds     82.40 -21.21 -159.78
# 28            Rikitea      PF    scattered clouds     75.74 -23.12 -134.97
# 30             Aitape      PG       broken clouds     80.65  -3.14  142.35
# 31           Simbahan      PH          light rain     84.06   6.30  120.58
# 33            Kavieng      PG           clear sky     83.89  -2.57  150.80
# 40       Puerto Ayora      EC          few clouds     82.40  -0.74  -90.35
#
#         Hotel Name
# City_ID
# 5
# 16
# 17
# 22
# 24
# 28
# 30
# 31
# 33
# 40

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

#Iterate through the DataFrame
for index, row in hotel_df.iterrows():
    
    #Get the latitude and longitude
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "lodging" and our latitude and longitude
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    #Make request and get the JSON data from the search
    hotels = requests.get(base_url, params=params).json()
    
    #Grab the first hotel from the results and store the name
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} & {Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# Add a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Save DataFrame as a CSV file
output_data_file = "weather_data/WeatherPy_vacation.csv"
#Export the City_Data into a CSV
hotel_df.to_csv(output_data_file, index_label="City_ID")
